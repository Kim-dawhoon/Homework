# %% [markdown]
# <a href="https://colab.research.google.com/github/Kim-dawhoon/Homework/blob/master/%EC%97%B4%EC%9C%A0%EC%B2%B4%EA%B3%B5%ED%95%99%EC%8B%A4%ED%97%98-2015009970-HW05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 과제
# 5번
#
# 파일 - 새 Python3 노트를 통해 새 노트북을 만드시오.
#
# 아래 작성된 코드 셀을 복사한 후 ## FIXME ## 부분을 수정하여 x, y, z의 3d plot을
# 출력하시오.
#
# 파일 - Github에 사본 저장을 통해 1번 과제에서 복사한 저장소에 아래와 같은
# 이름으로 저장하시오.
#
# 열유체공학실험-2015009970-HW05
#
# 다른 제목인 경우 미제출 처리 될 수 있음.

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %%
def homework05():
    theta = 2 * np.pi * np.random.random(1000)
    r = 6 * np.random.random(1000)
    x = np.ravel(r * np.sin(theta))
    y = np.ravel(r * np.cos(theta))
    z = np.exp(-0.1*x**2-0.1*y**2)
    return x, y, z

x, y, z = homework05()

ax = plt.axes(projection='3d')
# TODO
# 아래 ax.plot_trisurf 함수 내부 인자를 완성하시오.
ax.plot_trisurf(x, y, z,
                cmap='viridis', edgecolor='none')
ax.set_xlim(-5, 5); ax.set_ylim(-5, 5); ax.set_zlim(0, 1);
